# %% [markdown]
# # Convolutional Neural Networks
#
# ## Preliminaries
#
# In this practical session you will implement and train several Convolutional Neural Networks (CNNs) using the Keras framework with a Tensorflow backend. If you are not already familiar with Keras, you can go over the [following tutorial](https://github.com/tueimage/essential-skills/blob/master/keras.md). More detailed information on the different functionalities can be found in the [Keras library documentation](https://keras.io/).
#
# Note that for this set of exercise CPU-only Tensorflow, which you should already have installed, is sufficient (i.e. GPU-support is not required but it will make your experiments run faster).
#
# You are also required to use the `gryds` package for data augmentation that you can install directly from git: `pip install git+https://github.com/tueimage/gryds/`.
#
# You also have to install the Keras deep learning framework (if you have not done so already) by running `conda install keras`. Note that there are two implementations of Keras, one from https://keras.io/ and another one that ships with Tensorflow. Here we use the former.

# %% [markdown]
# ## MNIST
# We will first train a simple CNN to classify handwritten digits using the MNIST dataset. This dataset is often referred to as the "Hello world!" example of deep learning because it can be used to quickly illustrate a small neural network in action (and obtain a decent classification accuracy in the process). More information on it can be found [here](http://yann.lecun.com/exdb/mnist/).
#
# First, let's load the dataset and visualize some images.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# load the MNIST the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# scale the image intensities to the 0-1 range
x_train = (x_train / 255.0).astype(np.float32)
x_test = (x_test / 255.0).astype(np.float32)

# convert the data to channel-last
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# convert the labels to one-hot encoded
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

def plot_images(images, dim=(10, 10), figsize=(10, 10), title=''):
    
    plt.figure(figsize=figsize)
    
    for i in range(images.shape[0]):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(images[i], interpolation='nearest', cmap='gray_r')
        plt.axis('off')
    
    plt.tight_layout()
    plt.suptitle(title)
    plt.show()
    
plot_images(x_train[np.random.randint(0, x_train.shape[0], size=100)].reshape(100, 28, 28))

# %% [markdown]
# The MNIST classification task is quite simple: given an image, predict the digit that it contains. Thus, this is a 10-class classification problem.
#
# Let's define a simple network for the handwritten digit classification.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile and train the network (note that this could take a while).

# %%
from keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam

model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=12,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 45s 95ms/step - loss: 0.2536 - accuracy: 0.9219 - val_loss: 0.0519 - val_accuracy: 0.9825
# Epoch 2/12
# 469/469 [==============================] - 43s 91ms/step - loss: 0.0881 - accuracy: 0.9737 - val_loss: 0.0414 - val_accuracy: 0.9877
# Epoch 3/12
# 469/469 [==============================] - 42s 90ms/step - loss: 0.0653 - accuracy: 0.9802 - val_loss: 0.0448 - val_accuracy: 0.9858
# Epoch 4/12
# 469/469 [==============================] - 43s 92ms/step - loss: 0.0551 - accuracy: 0.9830 - val_loss: 0.0284 - val_accuracy: 0.9903
# Epoch 5/12
# 469/469 [==============================] - 44s 94ms/step - loss: 0.0452 - accuracy: 0.9860 - val_loss: 0.0302 - val_accuracy: 0.9904
# Epoch 6/12
# 469/469 [==============================] - 43s 91ms/step - loss: 0.0389 - accuracy: 0.9875 - val_loss: 0.0284 - val_accuracy: 0.9909
# Epoch 7/12
# 469/469 [==============================] - 44s 93ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.0279 - val_accuracy: 0.9909
# Epoch 8/12
# 469/469 [==============================] - 44s 93ms/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.0338 - val_accuracy: 0.9896
# Epoch 9/12
# 469/469 [==============================] - 45s 96ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 0.0291 - val_accuracy: 0.9905
# Epoch 10/12
# 469/469 [==============================] - 45s 95ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 0.0255 - val_accuracy: 0.9914
# Epoch 11/12
# 469/469 [==============================] - 43s 92ms/step - loss: 0.0241 - accuracy: 0.9919 - val_loss: 0.0311 - val_accuracy: 0.9912
# Epoch 12/12
# 469/469 [==============================] - 44s 93ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0318 - val_accuracy: 0.9908
# Test loss: 0.031754039227962494
# Test accuracy: 0.9908000230789185

# %% [markdown]
# Now that the model is trained, we can evaluate its performance on the independent test dataset.

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.031754039227962494
# Test accuracy: 0.9908000230789185

# %% [markdown]
# ## Fully-convolutional MNIST model
#
# Modify the model in the MNIST example in such a way that it only contains convolutional layers while keeping the same number of parameters. If you do the modification correctly, the two models will have the same behaviour (i.e. they will represent the same model, only with different implementation). Show this experimentally.

# %%
from keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
# Build the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (12,12), activation = 'relu'))
model.add(Conv2D(10,(1,1),activation='softmax'))
model.add(Flatten())

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 128)         1179776
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 10)          1290
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10)                0
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=12,
          verbose=1,
          validation_data=(x_test, y_test))

# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 95s 202ms/step - loss: 0.1701 - accuracy: 0.9494 - val_loss: 0.0557 - val_accuracy: 0.9822
# Epoch 2/12
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0478 - accuracy: 0.9851 - val_loss: 0.0373 - val_accuracy: 0.9881
# Epoch 3/12
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0320 - accuracy: 0.9898 - val_loss: 0.0331 - val_accuracy: 0.9893
# Epoch 4/12
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.0337 - val_accuracy: 0.9892
# Epoch 5/12
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0303 - val_accuracy: 0.9906
# Epoch 6/12
# 469/469 [==============================] - 78s 165ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0380 - val_accuracy: 0.9883
# Epoch 7/12
# 469/469 [==============================] - 79s 167ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0323 - val_accuracy: 0.9904
# Epoch 8/12
# 469/469 [==============================] - 79s 168ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0395 - val_accuracy: 0.9898
# Epoch 9/12
# 469/469 [==============================] - 87s 185ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0377 - val_accuracy: 0.9907
# Epoch 10/12
# 469/469 [==============================] - 84s 179ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0386 - val_accuracy: 0.9900
# Epoch 11/12
# 469/469 [==============================] - 82s 175ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0389 - val_accuracy: 0.9900
# Epoch 12/12
# 469/469 [==============================] - 85s 181ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0348 - val_accuracy: 0.9901
# Test loss: 0.03483051061630249
# Test accuracy: 0.9901000261306763

# %% [markdown]
# <font color='#770a0a'>Both the network containing dense layers, as well as the fully-convolutional network are composed of 1,199,882 parameters. The test accuracy are similar with values of respectively 0.9908 and 0.9901. Also the test loss is similar with values of respectively 0.0318 and 0.0348. This shows that both networks have same behaviour and performance. It is interesting to note that even though the results are the same, the training time for the fully-convolutional network was double the training time of the network containing dense layers, despite the same number of parameters. </font>

# %% [markdown]
# ## U-Net
# The U-Net convolutional neural network architecture was first developed for biomedical image segmentation and is to this day one of the most widely used methods for image segmentation. The details of the architecture can be found in the [original paper](https://arxiv.org/abs/1505.04597). In this practical we will build and train a U-Net network that is able to segment blood vessels in retinal images.
#
# ### Loading and visualizing the data
# The data for this task is taken from the [DRIVE](https://www.isi.uu.nl/Research/Databases/DRIVE/index.php) database. It consists of photographs of the retina, where the goal is to segment the blood vessels within. The dataset has a total of 40 photographs, divided in 20 images for training and 20 for testing. The images corresponding to the DRIVE test set can be found [here](https://www.dropbox.com/s/zk51wgupimw7jd9/DRIVE.zip?dl=0).
#
# Let's load the training set and visualize an image with the corresponding blood vessel segmentation. For training we will divide the data in a training and a validation set to monitor the model during training.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from glob import glob
from unet_utils import load_data

# location of the DRIVE dataset
data_folder = r"C:\\DRIVE\\"
train_paths = glob(data_folder + 'training/images/*.tif')
images, masks, segmentations = load_data(train_paths)

# print the shape of image dataset
print(images.shape)

plt.figure(figsize=(10, 8))

plt.subplot(1, 2, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(images[0])

plt.subplot(1, 2, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(segmentations[0][:, :, 0])

plt.show()

# divide in training and validation
train_images, val_images, train_masks, val_masks, train_segmentations, val_segmentations = train_test_split(
    images, masks, segmentations, test_size=0.2, random_state=7)

# print the shape of the training and valudation datasets
print(train_images.shape)
print(train_masks.shape)
print(train_segmentations.shape)
print(val_images.shape)
print(val_masks.shape)
print(val_segmentations.shape)
# Out:
# (20, 584, 565, 3)
# (16, 584, 565, 3)
# (16, 584, 565, 1)
# (16, 584, 565, 1)
# (4, 584, 565, 3)
# (4, 584, 565, 1)
# (4, 584, 565, 1)

# %% [markdown]
# ### Training a U-Net model
#
# You are already provided with implementation of the U-Net architecture in `unet_model.py`. This is a modular implementation and can be used to generate U-Net architectures with a variety of hyperparameters such as depth and number of feature maps. Before using the model, examine the code and documentation and make sure that you understand all the details.
#
# We will train a U-Net model using smaller patches extracted from the training images. Training the images on smaller patches requires less computation power and results in a more varied training dataset (it has the effect of data augmentation by image translation). Because a U-Net is a fully convolutional network it can be evaluated on inputs of different size (the output size will change according to the input size). Thus, although the model will be trained on smaller patches it can still be used to segment larger images with one pass through the model.

# %%
from unet_utils import extract_patches, preprocessing

# work with 32x32 patches
patch_size = (32, 32)

# 200 patches per image
patches_per_im = 200

# visualize a couple of patches as a visual check
patches, patches_segmentations = extract_patches(train_images, train_segmentations, patch_size, patches_per_im=1, seed=7)

print(patches.shape)

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 12))

for i in range(0, 3):
    axes[i, 0].axis('off')
    axes[i, 0].imshow(patches[i])
    axes[i, 1].axis('off')
    axes[i, 1].imshow(patches_segmentations[i][:, :, 0])
    axes[i, 2].axis('off')
    axes[i, 2].imshow(patches[i+5])
    axes[i, 3].axis('off')
    axes[i, 3].imshow(patches_segmentations[i+5][:, :, 0])

plt.show()
# Out:
# (16, 32, 32, 3)

# %%
# pad the validation data to fit the U-Net model
# images of shape (584, 565) shape result in concatenation error due to the odd number of columns

print("Old shape:", val_images.shape)

val_images, val_masks, val_segmentations = preprocessing(
    val_images, 
    val_masks, 
    val_segmentations, 
    desired_shape=(584, 584))
    
print("New shape:", val_images.shape)
# Out:
# Old shape: (4, 584, 565, 3)
# New shape: (4, 584, 584, 3)

# %%
import os
from unet_model import unet
from unet_utils import datagenerator
from keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

print(X_train.shape)
print(y_train.shape)

# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# print a summary of the model
# model.summary(line_length=120)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# train the model with the data generator, and save the training history
history = model.fit_generator(datagenerator(X_train, y_train, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# (1, 584, 565, 3)
# (1, 584, 565, 1)
# C:\Users\larsd\anaconda3\envs\8dm50\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 50/50 - 22s - loss: 0.5633 - accuracy: 0.7736 - val_loss: 0.6662 - val_accuracy: 0.6663
# Epoch 2/250
# 50/50 - 19s - loss: 0.3444 - accuracy: 0.9392 - val_loss: 0.8566 - val_accuracy: 0.6673
# Epoch 3/250
# 50/50 - 19s - loss: 0.2267 - accuracy: 0.9564 - val_loss: 0.2647 - val_accuracy: 0.9212
# Epoch 4/250
# 50/50 - 19s - loss: 0.1805 - accuracy: 0.9592 - val_loss: 0.2605 - val_accuracy: 0.9210
# Epoch 5/250
# 50/50 - 19s - loss: 0.1826 - accuracy: 0.9531 - val_loss: 0.3131 - val_accuracy: 0.9231
# Epoch 6/250
# 50/50 - 19s - loss: 0.1558 - accuracy: 0.9569 - val_loss: 0.3370 - val_accuracy: 0.9179
# Epoch 7/250
# 50/50 - 20s - loss: 0.1278 - accuracy: 0.9615 - val_loss: 0.3700 - val_accuracy: 0.9225
# Epoch 8/250
# 50/50 - 20s - loss: 0.1257 - accuracy: 0.9601 - val_loss: 0.2361 - val_accuracy: 0.9301
# Epoch 9/250
# 50/50 - 20s - loss: 0.1201 - accuracy: 0.9610 - val_loss: 0.2625 - val_accuracy: 0.9277
# Epoch 10/250
# 50/50 - 19s - loss: 0.1115 - accuracy: 0.9626 - val_loss: 0.2301 - val_accuracy: 0.9296
# Epoch 11/250
# 50/50 - 20s - loss: 0.1069 - accuracy: 0.9632 - val_loss: 0.2238 - val_accuracy: 0.9376
# Epoch 12/250
# 50/50 - 21s - loss: 0.1003 - accuracy: 0.9651 - val_loss: 0.1938 - val_accuracy: 0.9378
# Epoch 13/250
# 50/50 - 21s - loss: 0.1201 - accuracy: 0.9584 - val_loss: 0.4369 - val_accuracy: 0.8655
# Epoch 14/250
# 50/50 - 19s - loss: 0.1028 - accuracy: 0.9643 - val_loss: 0.1669 - val_accuracy: 0.9397
# Epoch 15/250
# 50/50 - 20s - loss: 0.1103 - accuracy: 0.9613 - val_loss: 43.5723 - val_accuracy: 0.4282
# Epoch 16/250
# 50/50 - 20s - loss: 0.1074 - accuracy: 0.9626 - val_loss: 0.8420 - val_accuracy: 0.8110
# Epoch 17/250
# 50/50 - 20s - loss: 0.1004 - accuracy: 0.9645 - val_loss: 0.1957 - val_accuracy: 0.9464
# Epoch 18/250
# 50/50 - 21s - loss: 0.0992 - accuracy: 0.9646 - val_loss: 0.1779 - val_accuracy: 0.9402
# Epoch 19/250
# 50/50 - 24s - loss: 0.1013 - accuracy: 0.9635 - val_loss: 0.6112 - val_accuracy: 0.7238
# Epoch 20/250
# 50/50 - 25s - loss: 0.0975 - accuracy: 0.9649 - val_loss: 0.3631 - val_accuracy: 0.8061
# Epoch 21/250
# 50/50 - 26s - loss: 0.0913 - accuracy: 0.9670 - val_loss: 0.1778 - val_accuracy: 0.9368
# Epoch 22/250
# 50/50 - 27s - loss: 0.0909 - accuracy: 0.9673 - val_loss: 0.1467 - val_accuracy: 0.9477
# Epoch 23/250
# 50/50 - 28s - loss: 0.0879 - accuracy: 0.9676 - val_loss: 0.1991 - val_accuracy: 0.9229
# Epoch 24/250
# 50/50 - 27s - loss: 0.0937 - accuracy: 0.9653 - val_loss: 0.2006 - val_accuracy: 0.9213
# Epoch 25/250
# 50/50 - 27s - loss: 0.0874 - accuracy: 0.9679 - val_loss: 0.2285 - val_accuracy: 0.9224
# Epoch 26/250
# 50/50 - 27s - loss: 0.0871 - accuracy: 0.9678 - val_loss: 0.1589 - val_accuracy: 0.9492
# Epoch 27/250
# 50/50 - 28s - loss: 0.0872 - accuracy: 0.9674 - val_loss: 0.1740 - val_accuracy: 0.9474
# Epoch 28/250
# 50/50 - 28s - loss: 0.0902 - accuracy: 0.9664 - val_loss: 0.2338 - val_accuracy: 0.9206
# Epoch 29/250
# 50/50 - 29s - loss: 0.0857 - accuracy: 0.9675 - val_loss: 0.2097 - val_accuracy: 0.9338
# Epoch 30/250
# 50/50 - 27s - loss: 0.0852 - accuracy: 0.9678 - val_loss: 0.1851 - val_accuracy: 0.9376
# Epoch 31/250
# 50/50 - 27s - loss: 0.0854 - accuracy: 0.9681 - val_loss: 0.1965 - val_accuracy: 0.9337
# Epoch 32/250
# 50/50 - 27s - loss: 0.0846 - accuracy: 0.9684 - val_loss: 0.1696 - val_accuracy: 0.9429
# Epoch 33/250
# 50/50 - 28s - loss: 0.0881 - accuracy: 0.9668 - val_loss: 0.1480 - val_accuracy: 0.9495
# Epoch 34/250
# 50/50 - 29s - loss: 0.0840 - accuracy: 0.9684 - val_loss: 0.2025 - val_accuracy: 0.9290
# Epoch 35/250
# 50/50 - 28s - loss: 0.0881 - accuracy: 0.9668 - val_loss: 0.1960 - val_accuracy: 0.9425
# Epoch 36/250
# 50/50 - 27s - loss: 0.0840 - accuracy: 0.9683 - val_loss: 0.2575 - val_accuracy: 0.9205
# Epoch 37/250
# 50/50 - 28s - loss: 0.0859 - accuracy: 0.9676 - val_loss: 0.1825 - val_accuracy: 0.9365

# %% [markdown]
# ### Visualizing the segmentation results

# %%
# run the model on one test image and show the results
from unet_utils import preprocessing

# test data paths
impaths_test = glob(data_folder + 'test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()

# %% [markdown]
# ## Data augmentation
#
# Implement random brightness augmentation of the image data by adding a random offset to the image intensity before passing them trough the network at training time. Train a model with random brightness augmentation and compare it to the baseline above.

# %%
import os
from unet_model import unet
from unet_utils import datagenerator_int
from keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

print(X_train.shape)
print(y_train.shape)

# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# print a summary of the model
# model.summary(line_length=120)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# train the model with the data generator, and save the training history
history = model.fit_generator(datagenerator_int(X_train, y_train, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# (1, 584, 565, 3)
# (1, 584, 565, 1)
# C:\Users\larsd\anaconda3\envs\8dm50\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 50/50 - 20s - loss: 0.5814 - accuracy: 0.7494 - val_loss: 0.3087 - val_accuracy: 0.9211
# Epoch 2/250
# 50/50 - 19s - loss: 0.3773 - accuracy: 0.9285 - val_loss: 5.5470 - val_accuracy: 0.0878
# Epoch 3/250
# 50/50 - 19s - loss: 0.2827 - accuracy: 0.9447 - val_loss: 0.2834 - val_accuracy: 0.9211
# Epoch 4/250
# 50/50 - 19s - loss: 0.2130 - accuracy: 0.9522 - val_loss: 0.2947 - val_accuracy: 0.9211
# Epoch 5/250
# 50/50 - 19s - loss: 0.1734 - accuracy: 0.9559 - val_loss: 0.3493 - val_accuracy: 0.9211
# Epoch 6/250
# 50/50 - 18s - loss: 0.1636 - accuracy: 0.9539 - val_loss: 0.3175 - val_accuracy: 0.9211
# Epoch 7/250
# 50/50 - 19s - loss: 0.1423 - accuracy: 0.9574 - val_loss: 0.4478 - val_accuracy: 0.9211
# Epoch 8/250
# 50/50 - 18s - loss: 0.1380 - accuracy: 0.9573 - val_loss: 0.3942 - val_accuracy: 0.9211
# Epoch 9/250
# 50/50 - 19s - loss: 0.1187 - accuracy: 0.9621 - val_loss: 0.3385 - val_accuracy: 0.9211
# Epoch 10/250
# 50/50 - 18s - loss: 0.1292 - accuracy: 0.9579 - val_loss: 0.3356 - val_accuracy: 0.9211
# Epoch 11/250
# 50/50 - 19s - loss: 0.1225 - accuracy: 0.9595 - val_loss: 0.4173 - val_accuracy: 0.9211
# Epoch 12/250
# 50/50 - 19s - loss: 0.1109 - accuracy: 0.9620 - val_loss: 0.4735 - val_accuracy: 0.9211
# Epoch 13/250
# 50/50 - 19s - loss: 0.1120 - accuracy: 0.9614 - val_loss: 0.2823 - val_accuracy: 0.9211
# Epoch 14/250
# 50/50 - 19s - loss: 0.1029 - accuracy: 0.9642 - val_loss: 0.3989 - val_accuracy: 0.9211
# Epoch 15/250
# 50/50 - 19s - loss: 0.1059 - accuracy: 0.9629 - val_loss: 0.4346 - val_accuracy: 0.9211
# Epoch 16/250
# 50/50 - 20s - loss: 0.1065 - accuracy: 0.9622 - val_loss: 0.4305 - val_accuracy: 0.9211
# Epoch 17/250
# 50/50 - 19s - loss: 0.1007 - accuracy: 0.9643 - val_loss: 0.5209 - val_accuracy: 0.9211
# Epoch 18/250
# 50/50 - 19s - loss: 0.1109 - accuracy: 0.9610 - val_loss: 0.7436 - val_accuracy: 0.9211
# Epoch 19/250
# 50/50 - 19s - loss: 0.1086 - accuracy: 0.9614 - val_loss: 0.5320 - val_accuracy: 0.9211
# Epoch 20/250
# 50/50 - 19s - loss: 0.1043 - accuracy: 0.9627 - val_loss: 0.5029 - val_accuracy: 0.9211
# Epoch 21/250
# 50/50 - 19s - loss: 0.1022 - accuracy: 0.9634 - val_loss: 0.4192 - val_accuracy: 0.9211
# Epoch 22/250
# 50/50 - 19s - loss: 0.0996 - accuracy: 0.9638 - val_loss: 0.4371 - val_accuracy: 0.9211
# Epoch 23/250
# 50/50 - 19s - loss: 0.0970 - accuracy: 0.9645 - val_loss: 0.5412 - val_accuracy: 0.9211
# Epoch 24/250
# 50/50 - 19s - loss: 0.0956 - accuracy: 0.9650 - val_loss: 0.5555 - val_accuracy: 0.9211
# Epoch 25/250
# 50/50 - 19s - loss: 0.0940 - accuracy: 0.9656 - val_loss: 0.5468 - val_accuracy: 0.9211
# Epoch 26/250
# 50/50 - 19s - loss: 0.1001 - accuracy: 0.9640 - val_loss: 0.4558 - val_accuracy: 0.9211
# Epoch 27/250
# 50/50 - 20s - loss: 0.0950 - accuracy: 0.9656 - val_loss: 0.3921 - val_accuracy: 0.9211
# Epoch 28/250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f2206b5e5bdf> in <module>
#      40                               validation_data=(val_images, val_segmentations),
#      41                               steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
# ---> 42                               callbacks=[early_stopping])
#
# ~\anaconda3\envs\8dm50\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1987         use_multiprocessing=use_multiprocessing,
#    1988         shuffle=shuffle,
# -> 1989         initial_epoch=initial_epoch)
#    1990
#    1991   @doc_controls.do_not_generate_docs
#
# ~\anaconda3\envs\8dm50\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\8dm50\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualizing the segmentation results

# %%
# run the model on one test image and show the results
from unet_utils import preprocessing

# test data paths
impaths_test = glob(data_folder + 'test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()

# %% [markdown]
# Implement data augmentation procedure that in addition to brightness augmentation also performs b-spline geometric augmentation using the [`gryds`](https://github.com/tueimage/gryds) package (you can look at the documentation of the package for an example on how to do that). Compare the new model with the baseline and the model that only performs brightness augmentation.

# %%
import os
from unet_model import unet
from unet_utils import datagenerator_int_bspline
from keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

print(X_train.shape)
print(y_train.shape)

# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# print a summary of the model
# model.summary(line_length=120)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# train the model with the data generator, and save the training history
history = model.fit_generator(datagenerator_int_bspline(X_train, y_train, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# (1, 584, 565, 3)
# (1, 584, 565, 1)
# C:\Users\larsd\anaconda3\envs\8dm50\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 50/50 - 20s - loss: 0.5982 - accuracy: 0.7070 - val_loss: 0.3614 - val_accuracy: 0.9211
# Epoch 2/250
# 50/50 - 19s - loss: 0.3609 - accuracy: 0.9326 - val_loss: 0.2772 - val_accuracy: 0.9211
# Epoch 3/250
# 50/50 - 19s - loss: 0.2700 - accuracy: 0.9447 - val_loss: 42.8318 - val_accuracy: 0.0860
# Epoch 4/250
# 50/50 - 19s - loss: 0.2246 - accuracy: 0.9471 - val_loss: 0.2997 - val_accuracy: 0.9211
# Epoch 5/250
# 50/50 - 19s - loss: 0.1729 - accuracy: 0.9548 - val_loss: 0.3129 - val_accuracy: 0.9211
# Epoch 6/250
# 50/50 - 18s - loss: 0.1653 - accuracy: 0.9533 - val_loss: 0.3179 - val_accuracy: 0.9211
# Epoch 7/250
# 50/50 - 19s - loss: 0.1384 - accuracy: 0.9594 - val_loss: 0.3364 - val_accuracy: 0.9211
# Epoch 8/250
# 50/50 - 18s - loss: 0.1274 - accuracy: 0.9600 - val_loss: 0.3173 - val_accuracy: 0.9211
# Epoch 9/250
# 50/50 - 19s - loss: 0.1201 - accuracy: 0.9614 - val_loss: 0.3358 - val_accuracy: 0.9211
# Epoch 10/250
# 50/50 - 19s - loss: 0.1165 - accuracy: 0.9612 - val_loss: 0.3449 - val_accuracy: 0.9211
# Epoch 11/250
# 50/50 - 19s - loss: 0.1176 - accuracy: 0.9603 - val_loss: 0.3142 - val_accuracy: 0.9211
# Epoch 12/250
# 50/50 - 18s - loss: 0.1096 - accuracy: 0.9626 - val_loss: 0.4318 - val_accuracy: 0.9211
# Epoch 13/250
# 50/50 - 19s - loss: 0.1054 - accuracy: 0.9635 - val_loss: 0.3928 - val_accuracy: 0.9211
# Epoch 14/250
# 50/50 - 19s - loss: 0.1104 - accuracy: 0.9622 - val_loss: 0.3416 - val_accuracy: 0.9211
# Epoch 15/250
# 50/50 - 19s - loss: 0.1054 - accuracy: 0.9633 - val_loss: 0.4093 - val_accuracy: 0.9211
# Epoch 16/250
# 50/50 - 19s - loss: 0.1069 - accuracy: 0.9621 - val_loss: 0.4609 - val_accuracy: 0.9211
# Epoch 17/250
# 50/50 - 22s - loss: 0.1044 - accuracy: 0.9628 - val_loss: 0.4299 - val_accuracy: 0.9211

# %% [markdown]
# # Exercises
#
# ## Number of parameters
#
# The first convolutional layer in the MNIST example has 320 parameters. The first fully connected layer has 1179,776 parameters. What do these parameters correspond to?
#
# The 1179,776 paramaters of the dense layer correspond to the weights of the 9216 input nodes $*$ 128 output nodes + 128 biases belonging to each output nodes.<br>
# The 320 parameters of the convolutional layer correspond to the 3$*$3 kernelsize * 32 number of filters + 32 biases belonging to each filter.
#
# <font color='#770a0a'>What is the general expression for the number of parameters of 1) a convolutional layer and 2) a fully-connected layer?</font> <br>
# 1) # parameters convolutional layer = $\text{# filters} * \text{kernelsize} + \text{# filters}$<br>
# 2) # parameters dense layer = $\text{# inputs} * \text{# outputs} + \text{# outputs} $
#
#
# ## U-Net architecture
#
# <font color='#770a0a'> What is the role of the skip connections in the U-Net neural network architecture? Will it be possible to train the exact same architecture with the skip connections omitted? If yes, what would be the expected result? If no, what would be the cause of the error?</font><br><br>
# In general, skip connections are used to skip layers in a neural network and feed the output of a layer to next layers, instead of only the subsequent layer. The skip connections in the U-Net architecture connect the encoder and decoder part which makes it possible to recover fine-grained details in the final prediction, e.g. recover the spatial information that is lost during downsampling in the encoder. <br><br>
# Source: https://theaisummer.com/skip-connections/
#
#
# ## Data augmentation
#
# <font color='#770a0a'>Why does data augmentation result in less overfitting? Can data augmentation be applied to the test samples? If yes, towards what goal? If no, what is preventing that?</font>
#
# By using data augmentation, the dataset becomes larger which makes it more representative to future testing sets. This is because increasing the dataset makes the model less able to overfit to the samples, resulting in a more generalized model.
# Data augmentation can be performed by applying basic image manipulations, such as geometric transformations and color space transformations, but also with Deep Learning approaches, such as Generative Adverserial Networks. <br>The underlying assumption is that by augmentation more information is to be extracted from the dataset. For example, in the case of the MNIST-dataset this assumption will be invalid when vertically flipping 6s and 9s at this will result in images with different labels. <br>
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
